# %%
import os

MODULE = "/Users/alifian/Documents/GitHub/data-vis-kakenhi"
os.chdir(MODULE)
os.getcwd()
# Out:
# '/Users/alifian/Documents/GitHub/data-vis-kakenhi'

# %%
# utils import
from database.database import load_researchers
from dataset.dataset import *

# load data, models, collections
en_data = load_en_data()
en_faiss = load_en_faiss()
en_model = load_en_model()
researchers = load_researchers()
# Out:
# loading data
# loading faiss index
# loading en keyword model
# Connecting to cluster

# %%
import pandas as pd
import numpy as np

def vector_search(query, model, index, num_results=10):
    """Tranforms query to vector using a pretrained, sentence-level 
    DistilBERT model and finds similar vectors using FAISS.
    Args:
        query (str): User query that should be more than a sentence long.
        model (sentence_transformers.SentenceTransformer.SentenceTransformer)
        index (`numpy.ndarray`): FAISS index that needs to be deserialized.
        num_results (int): Number of results to return.
    Returns:
        D (:obj:`numpy.array` of `float`): Distance between results and query.
        I (:obj:`numpy.array` of `int`): Paper ID of the results.
    
    """
    vector = model.encode(list(query))
    D, I = index.search(np.array(vector).astype("float32"), k=num_results)
    return D, I

def get_keywords(model, data, index, kw, num=10):
    ''' get a list of similar keywords

    Parameters
    ----------
        model : the model to be used for extracting keywords from
        data : the data frame that contains full information related to a given index
        kw : string querry
        num: number of resutls to be extracted (default is 20)

    Returns
    -------
        tuple of a list of strig keywords and a list of coresponding memberIDs
    
    '''

    # Load data and models
    D, I = vector_search([kw], model, index, num_results=num)
    set_kw_ids = set(data.id)
    

    kw_tar = list()
    member_id = list()
    id_type = list()

    # print(data)

    for id_ in I.flatten().tolist():
            if id_ in set_kw_ids:
                f = data[(data.id == id_)]
            else:
                continue
            kw_tar.append(f.keyword.values[0])
            member_id.append(f.memberID.values[0])
            id_type.append(f.memberID_type.values[0])

    
    df = pd.DataFrame({'kw': kw_tar, 'memid': member_id, 'idtype': id_type})
    df.memid = df.memid.astype(str)
    df.idtype = df.idtype.astype(str)
    # print(df)
    # df = df.groupby(['kw'])['memid'].apply(','.join ).reset_index()
    # print(df)

    return list(df['kw']), list(df['memid']), list(df['idtype'])

# %%
kw = "machine learning"

# %%
keywords_list, id_list, id_type = get_keywords(en_model, en_data, en_faiss, kw, 50)

# %%
def flatten_str_list(memid):
    return_list = list()
    for ids in memid:
        for idsplit in ids.split(','):
            return_list.append(idsplit)
    return return_list

# %%
ids = list(set(flatten_str_list(id_list)))

# %%
select_field = {
    "$project" :
       {
         "institution" : "$institutionName.en",
         "name" : "$name.en",
        "kakenhiID": "$kakenhiID",
         "_id" : 0
       }
    }

# %%
id_query = {"$or": [{ "researchmapID": { "$in": ids } }, { "kakenhiID": { "$in": ids } }]}
pipeline = [
    {"$match": {
        "$and": [
            id_query,
        ],
    }},
    select_field,
    {"$limit" :  100},
]

# %%
from pandas import DataFrame

# %%
df = DataFrame(list(researchers.aggregate(pipeline)))

# %%
df
# Out:
#                                           institution              name  \
# 0                       Tokyo Metropolitan University      CHIN WEIHONG
# 1                                    Osaka University       LI LIANGZHI
# 2                         Osaka Prefecture University  Roy Parthapratim
# 3   Okinawa Institute of Science and Technology Gr...      KATIC Jelena
# 4                                 Kanazawa University         Gary Ross
# ..                                                ...               ...
# 95                            The University of Tokyo      Berman Naomi
# 96                 International Christian University       PICHL Lukas
# 97  National Institute of Information and Communic...      Mano Hiroaki
# 98                                   Osaka University     TABATA Tomoji
# 99                             The University of Aizu        Ilic Peter
#
#    kakenhiID
# 0   10876650
# 1   10875545
# 2   10837222
# 3   10834947
# 4   10708142
# ..       ...
# 95  60814407
# 96  10343394
# 97  10571581
# 98  10249873
# 99  10511503
#
# [100 rows x 3 columns]

# %%
df[df["institution"]==inst][['name', 'kakenhiID']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/2w/0dhg3vhn3253vk3sr0wky78w0000gn/T/ipykernel_25653/1486790014.py in <module>
# ----> 1 df[df["institution"]==inst][['name', 'kakenhiID']]
#
# NameError: name 'inst' is not defined

# %%
return_data = list()

for inst in list(df['institution'].unique()):
    researcher_profiles = list()
    print(inst)
    filtered_df = df[df["institution"]==inst][['name', 'kakenhiID']]
    for idx in range(len(filtered_df)):
        profile_name = filtered_df.iloc[idx][0] # name
        kak_id = filtered_df.iloc[idx][1] # kakenhi ID
        ob = {"firstName": profile_name, "kakenhiID": kak_id}
        researcher_profiles.append(ob)
    print({"institution": inst, "researcherProfiles": researcher_profiles})
    return_data.append({"institution": inst, "researcherProfiles": researcher_profiles})
# Out:
# Tokyo Metropolitan University
# {'institution': 'Tokyo Metropolitan University', 'researcherProfiles': [{'firstName': 'CHIN WEIHONG', 'kakenhiID': '10876650'}, {'firstName': 'PETER GUENTERT', 'kakenhiID': '20392110'}]}
# Osaka University
# {'institution': 'Osaka University', 'researcherProfiles': [{'firstName': 'LI LIANGZHI', 'kakenhiID': '10875545'}, {'firstName': 'ORLOSKY JASON', 'kakenhiID': '10815111'}, {'firstName': 'Yoo Donghoon', 'kakenhiID': '20868541'}, {'firstName': 'Tamura Shinichi', 'kakenhiID': '30029540'}, {'firstName': 'SHIMIZU Masaki', 'kakenhiID': '20550304'}, {'firstName': 'MACPHERSON TOM', 'kakenhiID': '40821898'}, {'firstName': 'Nakagawa Ikuo', 'kakenhiID': '70647437'}, {'firstName': 'TAKAGI TATSUYA', 'kakenhiID': '80144517'}, {'firstName': 'TABATA Tomoji', 'kakenhiID': '10249873'}]}
# Osaka Prefecture University
# {'institution': 'Osaka Prefecture University', 'researcherProfiles': [{'firstName': 'Roy Parthapratim', 'kakenhiID': '10837222'}, {'firstName': 'Chiang YiHan', 'kakenhiID': '10824196'}]}
# Okinawa Institute of Science and Technology Graduate University
# {'institution': 'Okinawa Institute of Science and Technology Graduate University', 'researcherProfiles': [{'firstName': 'KATIC Jelena', 'kakenhiID': '10834947'}, {'firstName': 'Mikheyev Alexander', 'kakenhiID': '90601162'}, {'firstName': 'Shah Payal', 'kakenhiID': '30773220'}]}
# Kanazawa University
# {'institution': 'Kanazawa University', 'researcherProfiles': [{'firstName': 'Gary Ross', 'kakenhiID': '10708142'}]}
# Shinshu University
# {'institution': 'Shinshu University', 'researcherProfiles': [{'firstName': 'Kimura Fumikazu', 'kakenhiID': '10621849'}]}
# Chubu University
# {'institution': 'Chubu University', 'researcherProfiles': [{'firstName': 'USAMI Hiroyasu', 'kakenhiID': '10847669'}]}
# Tokyo University of Agriculture and Technology
# {'institution': 'Tokyo University of Agriculture and Technology', 'researcherProfiles': [{'firstName': 'NGUYEN TUAN CUONG', 'kakenhiID': '10814246'}]}
# The University of Tokyo
# {'institution': 'The University of Tokyo', 'researcherProfiles': [{'firstName': 'KAWAZOE YOSHIMASA', 'kakenhiID': '10621477'}, {'firstName': 'WESTFECHTEL THOMAS', 'kakenhiID': '30896551'}, {'firstName': 'Sciazko Anna', 'kakenhiID': '30898945'}, {'firstName': 'Entzinger Jorg', 'kakenhiID': '60600327'}, {'firstName': 'Han Jiaxin', 'kakenhiID': '50791456'}, {'firstName': 'Berman Naomi', 'kakenhiID': '60814407'}]}
# The University of Aizu
# {'institution': 'The University of Aizu', 'researcherProfiles': [{'firstName': 'HEO Younghyon', 'kakenhiID': '10631476'}, {'firstName': 'MARKOV Konstantin', 'kakenhiID': '80394998'}, {'firstName': 'Liu Yong', 'kakenhiID': '60325967'}, {'firstName': 'Julian Villegas', 'kakenhiID': '50706281'}, {'firstName': 'Ilic Peter', 'kakenhiID': '10511503'}]}
# Japan Advanced Institute of Science and Technology
# {'institution': 'Japan Advanced Institute of Science and Technology', 'researcherProfiles': [{'firstName': 'Schwartzman Gregory', 'kakenhiID': '20815261'}, {'firstName': 'Nguyen Minh Le', 'kakenhiID': '30509401'}]}
# Research Institute for Humanity and Nature
# {'institution': 'Research Institute for Humanity and Nature', 'researcherProfiles': [{'firstName': 'NguyenTien Hoang', 'kakenhiID': '20829379'}]}
# Tokyo Institute of Technology
# {'institution': 'Tokyo Institute of Technology', 'researcherProfiles': [{'firstName': 'Patmonoaji Anindityo', 'kakenhiID': '20899265'}]}
# Institute of Physical and Chemical Research
# {'institution': 'Institute of Physical and Chemical Research', 'researcherProfiles': [{'firstName': 'Tanaka Akinori', 'kakenhiID': '20791924'}, {'firstName': 'Zhao Qibin', 'kakenhiID': '30599618'}, {'firstName': 'AguilarLleyda David', 'kakenhiID': '40895653'}, {'firstName': 'Khan Emtiyaz', 'kakenhiID': '30858022'}, {'firstName': 'Gerofi Balazs', 'kakenhiID': '70633501'}, {'firstName': 'MESHGI Kourosh', 'kakenhiID': '80774835'}, {'firstName': 'Johansen Joshua', 'kakenhiID': '80625351'}, {'firstName': 'MIDDLETON STEVEN', 'kakenhiID': '60526797'}]}
# Doshisha University
# {'institution': 'Doshisha University', 'researcherProfiles': [{'firstName': 'Yamamoto Seiichi', 'kakenhiID': '20374100'}]}
# Nagasaki University
# {'institution': 'Nagasaki University', 'researcherProfiles': [{'firstName': 'SUZUKI Ikumi', 'kakenhiID': '20637730'}]}
# Kyushu University
# {'institution': 'Kyushu University', 'researcherProfiles': [{'firstName': 'ARIMURA Hidetaka', 'kakenhiID': '20287353'}, {'firstName': 'YAOKAI Feng', 'kakenhiID': '60363389'}]}
# Iwate Prefectural University
# {'institution': 'Iwate Prefectural University', 'researcherProfiles': [{'firstName': 'FUJITA Hamido', 'kakenhiID': '30244990'}]}
# Kochi National College of Technology
# {'institution': 'Kochi National College of Technology', 'researcherProfiles': [{'firstName': 'YAMAGUCHI Takumi', 'kakenhiID': '30230361'}]}
# Nagoya Bunri University
# {'institution': 'Nagoya Bunri University', 'researcherProfiles': [{'firstName': 'Zhou Xinxin', 'kakenhiID': '30262645'}]}
# Nara Institute of Science and Technology
# {'institution': 'Nara Institute of Science and Technology', 'researcherProfiles': [{'firstName': 'AMIN MD. ALTAFUL', 'kakenhiID': '30379531'}, {'firstName': '', 'kakenhiID': '80823525'}]}
# Waseda University
# {'institution': 'Waseda University', 'researcherProfiles': [{'firstName': 'SAYAMA Hiroki', 'kakenhiID': '30345425'}, {'firstName': 'Veszteg Robert', 'kakenhiID': '30597753'}, {'firstName': 'Schmitz Alexander', 'kakenhiID': '30729455'}, {'firstName': 'Takarada Yudai', 'kakenhiID': '70367093'}, {'firstName': 'Parque Victor', 'kakenhiID': '50745221'}]}
# Nagoya University
# {'institution': 'Nagoya University', 'researcherProfiles': [{'firstName': 'Otchia Christian', 'kakenhiID': '90761198'}, {'firstName': 'Abe Takashi', 'kakenhiID': '40645347'}]}
# Kyoto University
# {'institution': 'Kyoto University', 'researcherProfiles': [{'firstName': 'NGUYEN Canh Hao', 'kakenhiID': '90626889'}, {'firstName': 'Wu Yang', 'kakenhiID': '30750559'}, {'firstName': 'Ishizu Koichi', 'kakenhiID': '50314224'}]}
# Aoyama Gakuin University
# {'institution': 'Aoyama Gakuin University', 'researcherProfiles': [{'firstName': 'ETCHUYA Kenji', 'kakenhiID': '90806499'}]}
# National Institute of Advanced Industrial Science and Technology
# {'institution': 'National Institute of Advanced Industrial Science and Technology', 'researcherProfiles': [{'firstName': 'Steven Phillips', 'kakenhiID': '90344209'}, {'firstName': 'Nobu, Masaru Konishi', 'kakenhiID': '40805644'}, {'firstName': 'LEBLAY Julien', 'kakenhiID': '70757377'}]}
# St. Marianna University School of Medicine
# {'institution': 'St. Marianna University School of Medicine', 'researcherProfiles': [{'firstName': '', 'kakenhiID': '30814628'}]}
# Ritsumeikan University
# {'institution': 'Ritsumeikan University', 'researcherProfiles': [{'firstName': 'Batjargal Biligsaikhan', 'kakenhiID': '30725396'}, {'firstName': 'Chandler Damon', 'kakenhiID': '70765495'}]}
# Japan Aerospace EXploration Agency
# {'institution': 'Japan Aerospace EXploration Agency', 'researcherProfiles': [{'firstName': 'andreevamori adriana', 'kakenhiID': '30747499'}, {'firstName': 'Tasker Elizabeth', 'kakenhiID': '40620373'}, {'firstName': 'Andrea Sansica', 'kakenhiID': '80867797'}]}
# Ibaraki University
# {'institution': 'Ibaraki University', 'researcherProfiles': [{'firstName': 'ZHANG CHENG', 'kakenhiID': '40755089'}]}
# Kanazawa Medical University
# {'institution': 'Kanazawa Medical University', 'researcherProfiles': [{'firstName': 'Oda Hideto', 'kakenhiID': '40607967'}]}
# Hitotsubashi University
# {'institution': 'Hitotsubashi University', 'researcherProfiles': [{'firstName': 'Yamamoto Yuichi', 'kakenhiID': '40855178'}]}
# Kwansei Gakuin University
# {'institution': 'Kwansei Gakuin University', 'researcherProfiles': [{'firstName': 'Ishikawa Keichi', 'kakenhiID': '40259445'}]}
# Ryukoku University
# {'institution': 'Ryukoku University', 'researcherProfiles': [{'firstName': 'Lee Soo im', 'kakenhiID': '40288634'}]}
# National Institute of Information and Communications Technology
# {'institution': 'National Institute of Information and Communications Technology', 'researcherProfiles': [{'firstName': 'Marie Benjamin', 'kakenhiID': '30869433'}, {'firstName': 'shen peng', 'kakenhiID': '80773118'}, {'firstName': 'Mano Hiroaki', 'kakenhiID': '10571581'}]}
# Advanced Telecommunications Research Institute International
# {'institution': 'Advanced Telecommunications Research Institute International', 'researcherProfiles': [{'firstName': 'CALLAN Daniel', 'kakenhiID': '70374113'}]}
# Kitasato University
# {'institution': 'Kitasato University', 'researcherProfiles': [{'firstName': 'Fukuda Hiroshi', 'kakenhiID': '70238484'}]}
# Chukyo University
# {'institution': 'Chukyo University', 'researcherProfiles': [{'firstName': 'Hashimoto Manabu', 'kakenhiID': '70510832'}]}
# Kagawa University
# {'institution': 'Kagawa University', 'researcherProfiles': [{'firstName': 'Nishinaka Miwa', 'kakenhiID': '70770741'}]}
# National Institute for Materials Science
# {'institution': 'National Institute for Materials Science', 'researcherProfiles': [{'firstName': 'yoshikawa genki', 'kakenhiID': '70401172'}, {'firstName': 'WANG HONGXIN', 'kakenhiID': '60813756'}]}
# Tokyo Metropolitan Institute of Medical Science
# {'institution': 'Tokyo Metropolitan Institute of Medical Science', 'researcherProfiles': [{'firstName': 'Horiuchi Junjiro', 'kakenhiID': '80392364'}]}
# National Institutes of Biomedical Innovation, Health and Nutrition
# {'institution': 'National Institutes of Biomedical Innovation, Health and Nutrition', 'researcherProfiles': [{'firstName': 'Shandar Ahmad', 'kakenhiID': '80463298'}]}
# University of Tsukuba
# {'institution': 'University of Tsukuba', 'researcherProfiles': [{'firstName': 'Shen Biao', 'kakenhiID': '80730811'}]}
# Kyorin University
# {'institution': 'Kyorin University', 'researcherProfiles': [{'firstName': 'Malcolm Field', 'kakenhiID': '50381281'}]}
# Kio University
# {'institution': 'Kio University', 'researcherProfiles': [{'firstName': 'UEJI Kayoko', 'kakenhiID': '50390208'}]}
# Kochi University of Technology
# {'institution': 'Kochi University of Technology', 'researcherProfiles': [{'firstName': 'Daniels Paul', 'kakenhiID': '50307245'}]}
# Kanto Gakuin University
# {'institution': 'Kanto Gakuin University', 'researcherProfiles': [{'firstName': '', 'kakenhiID': '60323903'}]}
# Nagoya Institute of Technology
# {'institution': 'Nagoya Institute of Technology', 'researcherProfiles': [{'firstName': '', 'kakenhiID': '50836616'}]}
# National Astronomical Observatory of Japan
# {'institution': 'National Astronomical Observatory of Japan', 'researcherProfiles': [{'firstName': 'Wu Benjamin', 'kakenhiID': '50868718'}]}
# Hokkaido University
# {'institution': 'Hokkaido University', 'researcherProfiles': [{'firstName': 'Taylor Nicholas', 'kakenhiID': '50750824'}]}
# Kobe University
# {'institution': 'Kobe University', 'researcherProfiles': [{'firstName': 'Hascoet Tristan', 'kakenhiID': '60848448'}]}
# National Institute of Informatics
# {'institution': 'National Institute of Informatics', 'researcherProfiles': [{'firstName': '', 'kakenhiID': '60851730'}]}
# The University of Tokushima
# {'institution': 'The University of Tokushima', 'researcherProfiles': [{'firstName': 'Yamamoto Tetsuya', 'kakenhiID': '60779396'}]}
# International Christian University
# {'institution': 'International Christian University', 'researcherProfiles': [{'firstName': 'PICHL Lukas', 'kakenhiID': '10343394'}]}

# %%
return_data
# Out:
# [{'institution': 'Tokyo Metropolitan University',
#   'researcherProfiles': [{'firstName': 'CHIN WEIHONG',
#     'kakenhiID': '10876650'},
#    {'firstName': 'PETER GUENTERT', 'kakenhiID': '20392110'}]},
#  {'institution': 'Osaka University',
#   'researcherProfiles': [{'firstName': 'LI LIANGZHI', 'kakenhiID': '10875545'},
#    {'firstName': 'ORLOSKY JASON', 'kakenhiID': '10815111'},
#    {'firstName': 'Yoo Donghoon', 'kakenhiID': '20868541'},
#    {'firstName': 'Tamura Shinichi', 'kakenhiID': '30029540'},
#    {'firstName': 'SHIMIZU Masaki', 'kakenhiID': '20550304'},
#    {'firstName': 'MACPHERSON TOM', 'kakenhiID': '40821898'},
#    {'firstName': 'Nakagawa Ikuo', 'kakenhiID': '70647437'},
#    {'firstName': 'TAKAGI TATSUYA', 'kakenhiID': '80144517'},
#    {'firstName': 'TABATA Tomoji', 'kakenhiID': '10249873'}]},
#  {'institution': 'Osaka Prefecture University',
#   'researcherProfiles': [{'firstName': 'Roy Parthapratim',
#     'kakenhiID': '10837222'},
#    {'firstName': 'Chiang YiHan', 'kakenhiID': '10824196'}]},
#  {'institution': 'Okinawa Institute of Science and Technology Graduate University',
#   'researcherProfiles': [{'firstName': 'KATIC Jelena',
#     'kakenhiID': '10834947'},
#    {'firstName': 'Mikheyev Alexander', 'kakenhiID': '90601162'},
#    {'firstName': 'Shah Payal', 'kakenhiID': '30773220'}]},
#  {'institution': 'Kanazawa University',
#   'researcherProfiles': [{'firstName': 'Gary Ross', 'kakenhiID': '10708142'}]},
#  {'institution': 'Shinshu University',
#   'researcherProfiles': [{'firstName': 'Kimura Fumikazu',
#     'kakenhiID': '10621849'}]},
#  {'institution': 'Chubu University',
#   'researcherProfiles': [{'firstName': 'USAMI Hiroyasu',
#     'kakenhiID': '10847669'}]},
#  {'institution': 'Tokyo University of Agriculture and Technology',
#   'researcherProfiles': [{'firstName': 'NGUYEN TUAN CUONG',
#     'kakenhiID': '10814246'}]},
#  {'institution': 'The University of Tokyo',
#   'researcherProfiles': [{'firstName': 'KAWAZOE YOSHIMASA',
#     'kakenhiID': '10621477'},
#    {'firstName': 'WESTFECHTEL THOMAS', 'kakenhiID': '30896551'},
#    {'firstName': 'Sciazko Anna', 'kakenhiID': '30898945'},
#    {'firstName': 'Entzinger Jorg', 'kakenhiID': '60600327'},
#    {'firstName': 'Han Jiaxin', 'kakenhiID': '50791456'},
#    {'firstName': 'Berman Naomi', 'kakenhiID': '60814407'}]},
#  {'institution': 'The University of Aizu',
#   'researcherProfiles': [{'firstName': 'HEO Younghyon',
#     'kakenhiID': '10631476'},
#    {'firstName': 'MARKOV Konstantin', 'kakenhiID': '80394998'},
#    {'firstName': 'Liu Yong', 'kakenhiID': '60325967'},
#    {'firstName': 'Julian Villegas', 'kakenhiID': '50706281'},
#    {'firstName': 'Ilic Peter', 'kakenhiID': '10511503'}]},
#  {'institution': 'Japan Advanced Institute of Science and Technology',
#   'researcherProfiles': [{'firstName': 'Schwartzman Gregory',
#     'kakenhiID': '20815261'},
#    {'firstName': 'Nguyen Minh Le', 'kakenhiID': '30509401'}]},
#  {'institution': 'Research Institute for Humanity and Nature',
#   'researcherProfiles': [{'firstName': 'NguyenTien Hoang',
#     'kakenhiID': '20829379'}]},
#  {'institution': 'Tokyo Institute of Technology',
#   'researcherProfiles': [{'firstName': 'Patmonoaji Anindityo',
#     'kakenhiID': '20899265'}]},
#  {'institution': 'Institute of Physical and Chemical Research',
#   'researcherProfiles': [{'firstName': 'Tanaka Akinori',
#     'kakenhiID': '20791924'},
#    {'firstName': 'Zhao Qibin', 'kakenhiID': '30599618'},
#    {'firstName': 'AguilarLleyda David', 'kakenhiID': '40895653'},
#    {'firstName': 'Khan Emtiyaz', 'kakenhiID': '30858022'},
#    {'firstName': 'Gerofi Balazs', 'kakenhiID': '70633501'},
#    {'firstName': 'MESHGI Kourosh', 'kakenhiID': '80774835'},
#    {'firstName': 'Johansen Joshua', 'kakenhiID': '80625351'},
#    {'firstName': 'MIDDLETON STEVEN', 'kakenhiID': '60526797'}]},
#  {'institution': 'Doshisha University',
#   'researcherProfiles': [{'firstName': 'Yamamoto Seiichi',
#     'kakenhiID': '20374100'}]},
#  {'institution': 'Nagasaki University',
#   'researcherProfiles': [{'firstName': 'SUZUKI Ikumi',
#     'kakenhiID': '20637730'}]},
#  {'institution': 'Kyushu University',
#   'researcherProfiles': [{'firstName': 'ARIMURA Hidetaka',
#     'kakenhiID': '20287353'},
#    {'firstName': 'YAOKAI Feng', 'kakenhiID': '60363389'}]},
#  {'institution': 'Iwate Prefectural University',
#   'researcherProfiles': [{'firstName': 'FUJITA Hamido',
#     'kakenhiID': '30244990'}]},
#  {'institution': 'Kochi National College of Technology',
#   'researcherProfiles': [{'firstName': 'YAMAGUCHI Takumi',
#     'kakenhiID': '30230361'}]},
#  {'institution': 'Nagoya Bunri University',
#   'researcherProfiles': [{'firstName': 'Zhou Xinxin',
#     'kakenhiID': '30262645'}]},
#  {'institution': 'Nara Institute of Science and Technology',
#   'researcherProfiles': [{'firstName': 'AMIN MD. ALTAFUL',
#     'kakenhiID': '30379531'},
#    {'firstName': '', 'kakenhiID': '80823525'}]},
#  {'institution': 'Waseda University',
#   'researcherProfiles': [{'firstName': 'SAYAMA Hiroki',
#     'kakenhiID': '30345425'},
#    {'firstName': 'Veszteg Robert', 'kakenhiID': '30597753'},
#    {'firstName': 'Schmitz Alexander', 'kakenhiID': '30729455'},
#    {'firstName': 'Takarada Yudai', 'kakenhiID': '70367093'},
#    {'firstName': 'Parque Victor', 'kakenhiID': '50745221'}]},
#  {'institution': 'Nagoya University',
#   'researcherProfiles': [{'firstName': 'Otchia Christian',
#     'kakenhiID': '90761198'},
#    {'firstName': 'Abe Takashi', 'kakenhiID': '40645347'}]},
#  {'institution': 'Kyoto University',
#   'researcherProfiles': [{'firstName': 'NGUYEN Canh Hao',
#     'kakenhiID': '90626889'},
#    {'firstName': 'Wu Yang', 'kakenhiID': '30750559'},
#    {'firstName': 'Ishizu Koichi', 'kakenhiID': '50314224'}]},
#  {'institution': 'Aoyama Gakuin University',
#   'researcherProfiles': [{'firstName': 'ETCHUYA Kenji',
#     'kakenhiID': '90806499'}]},
#  {'institution': 'National Institute of Advanced Industrial Science and Technology',
#   'researcherProfiles': [{'firstName': 'Steven Phillips',
#     'kakenhiID': '90344209'},
#    {'firstName': 'Nobu, Masaru Konishi', 'kakenhiID': '40805644'},
#    {'firstName': 'LEBLAY Julien', 'kakenhiID': '70757377'}]},
#  {'institution': 'St. Marianna University School of Medicine',
#   'researcherProfiles': [{'firstName': '', 'kakenhiID': '30814628'}]},
#  {'institution': 'Ritsumeikan University',
#   'researcherProfiles': [{'firstName': 'Batjargal Biligsaikhan',
#     'kakenhiID': '30725396'},
#    {'firstName': 'Chandler Damon', 'kakenhiID': '70765495'}]},
#  {'institution': 'Japan Aerospace EXploration Agency',
#   'researcherProfiles': [{'firstName': 'andreevamori adriana',
#     'kakenhiID': '30747499'},
#    {'firstName': 'Tasker Elizabeth', 'kakenhiID': '40620373'},
#    {'firstName': 'Andrea Sansica', 'kakenhiID': '80867797'}]},
#  {'institution': 'Ibaraki University',
#   'researcherProfiles': [{'firstName': 'ZHANG CHENG',
#     'kakenhiID': '40755089'}]},
#  {'institution': 'Kanazawa Medical University',
#   'researcherProfiles': [{'firstName': 'Oda Hideto',
#     'kakenhiID': '40607967'}]},
#  {'institution': 'Hitotsubashi University',
#   'researcherProfiles': [{'firstName': 'Yamamoto Yuichi',
#     'kakenhiID': '40855178'}]},
#  {'institution': 'Kwansei Gakuin University',
#   'researcherProfiles': [{'firstName': 'Ishikawa Keichi',
#     'kakenhiID': '40259445'}]},
#  {'institution': 'Ryukoku University',
#   'researcherProfiles': [{'firstName': 'Lee Soo im',
#     'kakenhiID': '40288634'}]},
#  {'institution': 'National Institute of Information and Communications Technology',
#   'researcherProfiles': [{'firstName': 'Marie Benjamin',
#     'kakenhiID': '30869433'},
#    {'firstName': 'shen peng', 'kakenhiID': '80773118'},
#    {'firstName': 'Mano Hiroaki', 'kakenhiID': '10571581'}]},
#  {'institution': 'Advanced Telecommunications Research Institute International',
#   'researcherProfiles': [{'firstName': 'CALLAN Daniel',
#     'kakenhiID': '70374113'}]},
#  {'institution': 'Kitasato University',
#   'researcherProfiles': [{'firstName': 'Fukuda Hiroshi',
#     'kakenhiID': '70238484'}]},
#  {'institution': 'Chukyo University',
#   'researcherProfiles': [{'firstName': 'Hashimoto Manabu',
#     'kakenhiID': '70510832'}]},
#  {'institution': 'Kagawa University',
#   'researcherProfiles': [{'firstName': 'Nishinaka Miwa',
#     'kakenhiID': '70770741'}]},
#  {'institution': 'National Institute for Materials Science',
#   'researcherProfiles': [{'firstName': 'yoshikawa genki',
#     'kakenhiID': '70401172'},
#    {'firstName': 'WANG HONGXIN', 'kakenhiID': '60813756'}]},
#  {'institution': 'Tokyo Metropolitan Institute of Medical Science',
#   'researcherProfiles': [{'firstName': 'Horiuchi Junjiro',
#     'kakenhiID': '80392364'}]},
#  {'institution': 'National Institutes of Biomedical Innovation, Health and Nutrition',
#   'researcherProfiles': [{'firstName': 'Shandar Ahmad',
#     'kakenhiID': '80463298'}]},
#  {'institution': 'University of Tsukuba',
#   'researcherProfiles': [{'firstName': 'Shen Biao', 'kakenhiID': '80730811'}]},
#  {'institution': 'Kyorin University',
#   'researcherProfiles': [{'firstName': 'Malcolm Field',
#     'kakenhiID': '50381281'}]},
#  {'institution': 'Kio University',
#   'researcherProfiles': [{'firstName': 'UEJI Kayoko',
#     'kakenhiID': '50390208'}]},
#  {'institution': 'Kochi University of Technology',
#   'researcherProfiles': [{'firstName': 'Daniels Paul',
#     'kakenhiID': '50307245'}]},
#  {'institution': 'Kanto Gakuin University',
#   'researcherProfiles': [{'firstName': '', 'kakenhiID': '60323903'}]},
#  {'institution': 'Nagoya Institute of Technology',
#   'researcherProfiles': [{'firstName': '', 'kakenhiID': '50836616'}]},
#  {'institution': 'National Astronomical Observatory of Japan',
#   'researcherProfiles': [{'firstName': 'Wu Benjamin',
#     'kakenhiID': '50868718'}]},
#  {'institution': 'Hokkaido University',
#   'researcherProfiles': [{'firstName': 'Taylor Nicholas',
#     'kakenhiID': '50750824'}]},
#  {'institution': 'Kobe University',
#   'researcherProfiles': [{'firstName': 'Hascoet Tristan',
#     'kakenhiID': '60848448'}]},
#  {'institution': 'National Institute of Informatics',
#   'researcherProfiles': [{'firstName': '', 'kakenhiID': '60851730'}]},
#  {'institution': 'The University of Tokushima',
#   'researcherProfiles': [{'firstName': 'Yamamoto Tetsuya',
#     'kakenhiID': '60779396'}]},
#  {'institution': 'International Christian University',
#   'researcherProfiles': [{'firstName': 'PICHL Lukas',
#     'kakenhiID': '10343394'}]}]

# %%
return_format = [{
    "institution": "Turnabout",
    "relatedResearchers": 306,
    "researcherProfiles": [
      {
        "firstName": "Ines",
        "lastName": "Bean",
        "papers": [
          {
            "paperName":
              "Ea exercitation reprehenderit minim magna sit consequat elit occaecat qui duis veniam.",
          },
          {
            "paperName":
              "Voluptate incididunt consequat qui dolor dolore cupidatat duis do quis nulla.",
          },
          {
            "paperName":
              "Excepteur ea laboris aute mollit culpa anim Lorem sit do ipsum ullamco labore sit amet.",
          },
          {
            "paperName":
              "Est adipisicing consectetur aliqua Lorem ex sunt ex sit voluptate.",
          },
          {
            "paperName":
              "Ex anim exercitation ut nostrud et anim nostrud dolore adipisicing.",
          },
        ],
      }]
}]
