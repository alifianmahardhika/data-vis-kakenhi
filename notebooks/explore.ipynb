# %%
import os

MODULE = "/Users/alifian/Documents/GitHub/data-vis-kakenhi"
os.chdir(MODULE)
os.getcwd()
# Out:
# '/Users/alifian/Documents/GitHub/data-vis-kakenhi'

# %%
# utils import
from database.database import load_researchers
from dataset.dataset import *

# load data, models, collections
en_data = load_en_data()
en_faiss = load_en_faiss()
en_model = load_en_model()
researchers = load_researchers()
# Out:
# loading data
# loading faiss index
# loading en keyword model
# Connecting to cluster

# %%
import pandas as pd
import numpy as np

def vector_search(query, model, index, num_results=10):
    """Tranforms query to vector using a pretrained, sentence-level 
    DistilBERT model and finds similar vectors using FAISS.
    Args:
        query (str): User query that should be more than a sentence long.
        model (sentence_transformers.SentenceTransformer.SentenceTransformer)
        index (`numpy.ndarray`): FAISS index that needs to be deserialized.
        num_results (int): Number of results to return.
    Returns:
        D (:obj:`numpy.array` of `float`): Distance between results and query.
        I (:obj:`numpy.array` of `int`): Paper ID of the results.
    
    """
    vector = model.encode(list(query))
    D, I = index.search(np.array(vector).astype("float32"), k=num_results)
    return D, I

def get_keywords(model, data, index, kw, num=10):
    ''' get a list of similar keywords

    Parameters
    ----------
        model : the model to be used for extracting keywords from
        data : the data frame that contains full information related to a given index
        kw : string querry
        num: number of resutls to be extracted (default is 20)

    Returns
    -------
        tuple of a list of strig keywords and a list of coresponding memberIDs
    
    '''

    # Load data and models
    D, I = vector_search([kw], model, index, num_results=num)
    set_kw_ids = set(data.id)
    

    kw_tar = list()
    member_id = list()
    id_type = list()

    # print(data)

    for id_ in I.flatten().tolist():
            if id_ in set_kw_ids:
                f = data[(data.id == id_)]
            else:
                continue
            kw_tar.append(f.keyword.values[0])
            member_id.append(f.memberID.values[0])
            id_type.append(f.memberID_type.values[0])

    
    df = pd.DataFrame({'kw': kw_tar, 'memid': member_id, 'idtype': id_type})
    df.memid = df.memid.astype(str)
    df.idtype = df.idtype.astype(str)
    # print(df)
    # df = df.groupby(['kw'])['memid'].apply(','.join ).reset_index()
    # print(df)

    return list(df['kw']), list(df['memid']), list(df['idtype'])

# %%
kw = "machine learning"

# %%
keywords_list, id_list, id_type = get_keywords(en_model, en_data, en_faiss, kw, 50)

# %%
def flatten_str_list(memid):
    return_list = list()
    for ids in memid:
        for idsplit in ids.split(','):
            return_list.append(idsplit)
    return return_list

# %%
ids = list(set(flatten_str_list(id_list)))

# %%
select_field = {
    "$project" :
       {
         "institution" : "$institutionName.en",
         "name" : "$name.en",
         "_id" : 0
       }
    }

# %%
id_query = {"$or": [{ "researchmapID": { "$in": ids } }, { "kakenhiID": { "$in": ids } }]}
pipeline = [
    {"$match": {
        "$and": [
            id_query,
        ],
    }},
    select_field,
    {"$limit" :  100},
]

# %%
from pandas import DataFrame

# %%
df = DataFrame(list(researchers.aggregate(pipeline)))

# %%
df
# Out:
#                                           institution  \
# 0                              Ritsumeikan University
# 1   Okinawa Institute of Science and Technology Gr...
# 2                                   Tohoku University
# 3                 Ritsumeikan Asia Pacific University
# 4                                  Okayama University
# 5                                    Osaka University
# 6                                    Meiji University
# 7                       Tokyo Metropolitan University
# 8                                   Nagoya University
# 9                                  Saitama University
# 10                            Hitotsubashi University
# 11                                   Kyoto University
# 12                Tokyo Medical and Dental University
# 13                                   Kyoto University
# 14                        Tokyo University of Science
# 15                                  Tohoku University
# 16                Tokyo University of Foreign Studies
# 17              National Institute of Health Sciences
# 18                                  Kyushu University
# 19                                Kanazawa University
# 20                                   Kyoto University
# 21                            The University of Tokyo
# 22                            The University of Tokyo
# 23                                   Kyoto University
# 24                                   Shiga University
# 25                       Aichi Prefectural University
# 26                      Tokyo Institute of Technology
# 27                 The University of Shiga Prefecture
# 28        Institute of Physical and Chemical Research
# 29                Ritsumeikan Asia Pacific University
# 30                                 Okayama University
#
#                            name
# 0                 YAMADA Mayumi
# 1              VELASQUE Mariana
# 2
# 3                   LEE Timothy
# 4                 HAYAKAWA Toru
# 5                 Nakai Hiroshi
# 6               Adams Andrew A.
# 7              GROISARD Jocelyn
# 8                   mangyo eiji
# 9                      Bez Neal
# 10                Akter Shamima
# 11                      C Pavin
# 12                 Uehara Naoko
# 13            Iyemori Toshihiko
# 14                 KATO Keiichi
# 15                 Nagai Hiroki
# 16  Rocha de Sousa Lucio Manuel
# 17               Yokota Satoshi
# 18                   Huixin Liu
# 19               YOSHIMURA Yuko
# 20           MIYASHITA Masahiro
# 21            Woodward Jonathan
# 22               Loetstedt Erik
# 23     Vincenot ChristianErnest
# 24                Sato Tomokazu
# 25                BRUNOTTE JOSH
# 26                Maity Basudev
# 27   JIMENEZ VERDEJO Juan Ramon
# 28               Casolino Marco
# 29            MANTELLO Peter A.
# 30                RUCYNSKI John

# %%
return_data = list()
for inst in list(df['institution'].unique()):
    researcher_profiles = list()
    print(inst)
    for profile_name in list(df[df["institution"]==inst]['name']):
        ob = {"firstName": profile_name}
        researcher_profiles.append(ob)
#     print({"institution": inst, "researcherProfiles": researcher_profiles})
    return_data.append({"institution": inst, "researcherProfiles": researcher_profiles})
# Out:
# Ritsumeikan University
# Okinawa Institute of Science and Technology Graduate University
# Tohoku University
# Ritsumeikan Asia Pacific University
# Okayama University
# Osaka University
# Meiji University
# Tokyo Metropolitan University
# Nagoya University
# Saitama University
# Hitotsubashi University
# Kyoto University
# Tokyo Medical and Dental University
# Tokyo University of Science
# Tokyo University of Foreign Studies
# National Institute of Health Sciences
# Kyushu University
# Kanazawa University
# The University of Tokyo
# Shiga University
# Aichi Prefectural University
# Tokyo Institute of Technology
# The University of Shiga Prefecture
# Institute of Physical and Chemical Research

# %%
return_data
# Out:
# [{'institution': 'Ritsumeikan University',
#   'researcherProfiles': [{'firstName': 'YAMADA Mayumi'}]},
#  {'institution': 'Okinawa Institute of Science and Technology Graduate University',
#   'researcherProfiles': [{'firstName': 'VELASQUE Mariana'}]},
#  {'institution': 'Tohoku University',
#   'researcherProfiles': [{'firstName': ''}, {'firstName': 'Nagai Hiroki'}]},
#  {'institution': 'Ritsumeikan Asia Pacific University',
#   'researcherProfiles': [{'firstName': 'LEE Timothy'},
#    {'firstName': 'MANTELLO Peter A.'}]},
#  {'institution': 'Okayama University',
#   'researcherProfiles': [{'firstName': 'HAYAKAWA Toru'},
#    {'firstName': 'RUCYNSKI John'}]},
#  {'institution': 'Osaka University',
#   'researcherProfiles': [{'firstName': 'Nakai Hiroshi'}]},
#  {'institution': 'Meiji University',
#   'researcherProfiles': [{'firstName': 'Adams Andrew A.'}]},
#  {'institution': 'Tokyo Metropolitan University',
#   'researcherProfiles': [{'firstName': 'GROISARD Jocelyn'}]},
#  {'institution': 'Nagoya University',
#   'researcherProfiles': [{'firstName': 'mangyo eiji'}]},
#  {'institution': 'Saitama University',
#   'researcherProfiles': [{'firstName': 'Bez Neal'}]},
#  {'institution': 'Hitotsubashi University',
#   'researcherProfiles': [{'firstName': 'Akter Shamima'}]},
#  {'institution': 'Kyoto University',
#   'researcherProfiles': [{'firstName': 'C Pavin'},
#    {'firstName': 'Iyemori Toshihiko'},
#    {'firstName': 'MIYASHITA Masahiro'},
#    {'firstName': 'Vincenot ChristianErnest'}]},
#  {'institution': 'Tokyo Medical and Dental University',
#   'researcherProfiles': [{'firstName': 'Uehara Naoko'}]},
#  {'institution': 'Tokyo University of Science',
#   'researcherProfiles': [{'firstName': 'KATO Keiichi'}]},
#  {'institution': 'Tokyo University of Foreign Studies',
#   'researcherProfiles': [{'firstName': 'Rocha de Sousa Lucio Manuel'}]},
#  {'institution': 'National Institute of Health Sciences',
#   'researcherProfiles': [{'firstName': 'Yokota Satoshi'}]},
#  {'institution': 'Kyushu University',
#   'researcherProfiles': [{'firstName': 'Huixin Liu'}]},
#  {'institution': 'Kanazawa University',
#   'researcherProfiles': [{'firstName': 'YOSHIMURA Yuko'}]},
#  {'institution': 'The University of Tokyo',
#   'researcherProfiles': [{'firstName': 'Woodward Jonathan'},
#    {'firstName': 'Loetstedt Erik'}]},
#  {'institution': 'Shiga University',
#   'researcherProfiles': [{'firstName': 'Sato Tomokazu'}]},
#  {'institution': 'Aichi Prefectural University',
#   'researcherProfiles': [{'firstName': 'BRUNOTTE JOSH'}]},
#  {'institution': 'Tokyo Institute of Technology',
#   'researcherProfiles': [{'firstName': 'Maity Basudev'}]},
#  {'institution': 'The University of Shiga Prefecture',
#   'researcherProfiles': [{'firstName': 'JIMENEZ VERDEJO Juan Ramon'}]},
#  {'institution': 'Institute of Physical and Chemical Research',
#   'researcherProfiles': [{'firstName': 'Casolino Marco'}]}]

# %%
return_format = [{
    "institution": "Turnabout",
    "relatedResearchers": 306,
    "researcherProfiles": [
      {
        "firstName": "Ines",
        "lastName": "Bean",
        "papers": [
          {
            "paperName":
              "Ea exercitation reprehenderit minim magna sit consequat elit occaecat qui duis veniam.",
          },
          {
            "paperName":
              "Voluptate incididunt consequat qui dolor dolore cupidatat duis do quis nulla.",
          },
          {
            "paperName":
              "Excepteur ea laboris aute mollit culpa anim Lorem sit do ipsum ullamco labore sit amet.",
          },
          {
            "paperName":
              "Est adipisicing consectetur aliqua Lorem ex sunt ex sit voluptate.",
          },
          {
            "paperName":
              "Ex anim exercitation ut nostrud et anim nostrud dolore adipisicing.",
          },
        ],
      }]
}]
